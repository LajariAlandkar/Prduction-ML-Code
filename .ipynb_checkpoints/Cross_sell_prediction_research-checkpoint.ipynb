# %% [markdown]
# # Health Insurance Cross Sell Prediction

# %% [markdown]
# About Data:
# 1. Variable 	Definition
# 2. id :	Unique ID for the customer
# 3. Gender :	Gender of the customer
# 4. Age :	Age of the customer
# 5. Driving_License: 	0 : Customer does not have DL, 1 : Customer already has DL
# 6. Region_Code: 	Unique code for the region of the customer
# 7. Previously_Insured: 	1 : Customer already has Vehicle Insurance, 0 : Customer doesn't have Vehicle Insurance
# 8. Vehicle_Age: 	Age of the Vehicle
# 9. Vehicle_Damage: 	1 : Customer got his/her vehicle damaged in the past. 0 : Customer didn't get his/her vehicle damaged in the past.
# 10. Annual_Premium: 	The amount customer needs to pay as premium in the year
# 11. PolicySalesChannel: 	Anonymized Code for the channel of outreaching to the customer ie. Different Agents, Over Mail, Over Phone, In Person, etc.
# 12. Vintage: 	Number of Days, Customer has been associated with the company
# 13. Response: 	1 : Customer is interested, 0 : Customer is not interested

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load Data

train = pd.read_csv('train/train.csv')
test = pd.read_csv('test/test.csv')

train.shape, test.shape
# Out:
# ((381109, 12), (127037, 11))

# %%
train.describe(include='all')
# Out:
#                    id  Gender            Age  Driving_License    Region_Code  \
# count   381109.000000  381109  381109.000000    381109.000000  381109.000000
# unique            NaN       2            NaN              NaN            NaN
# top               NaN    Male            NaN              NaN            NaN
# freq              NaN  206089            NaN              NaN            NaN
# mean    190555.000000     NaN      38.822584         0.997869      26.388807
# std     110016.836208     NaN      15.511611         0.046110      13.229888
# min          1.000000     NaN      20.000000         0.000000       0.000000
# 25%      95278.000000     NaN      25.000000         1.000000      15.000000
# 50%     190555.000000     NaN      36.000000         1.000000      28.000000
# 75%     285832.000000     NaN      49.000000         1.000000      35.000000
# max     381109.000000     NaN      85.000000         1.000000      52.000000
#
# ...

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
# Converting to categorical type
# cat_cols = ['Region_Code', 'Policy_Sales_Channel']
# train[cat_cols] = train[cat_cols].astype('category')

# %%
# Response distribution

train['Response'].value_counts(normalize=True).plot(kind= 'bar')

train_0 = train[train['Response']==0]
train_1 = train[train['Response']==1]

# %%
sns.boxplot(x='Response',y='Age', data=train)

# %%
plt.hist(train_0['Age'],alpha=0.5, bins=5, label='0')
plt.hist(train_1['Age'],alpha=0.5, bins=5,label ='1')
plt.legend()

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize=(15,5))
train_0['Driving_License'].value_counts().plot(kind='bar',ax=ax1)
train_1['Driving_License'].value_counts().plot(kind='bar',ax=ax2)

# %%
train_1['Driving_License'].value_counts(normalize=True)
# Out:
# 1    0.999122
# 0    0.000878
# Name: Driving_License, dtype: float64

# %%
train_0['Driving_License'].value_counts(normalize=True)
# Out:
# 1    0.997694
# 0    0.002306
# Name: Driving_License, dtype: float64

# %%
train.groupby(['Region_Code','Response']).size().unstack().plot(kind='bar',stacked=True, figsize=(15,7))

# %%
train.groupby(['Previously_Insured','Response']).size().unstack().plot(kind='bar',stacked=True)

# %%
### Will perform chi square test for above variable

# %%
sns.boxplot(x='Response',y='Annual_Premium',data=train)

# %%
plt.hist(train_0['Annual_Premium'],alpha=0.5, bins=20, label='0')
plt.hist(train_1['Annual_Premium'],alpha=0.5, bins=20, label='1')
plt.legend()

# %%
sns.boxplot(data = train, x='Response', y='Annual_Premium')

# %%
train.groupby(['Vehicle_Age','Response']).size().unstack().plot(kind='bar',stacked=True)

# %%
train.groupby(['Vehicle_Damage','Response']).size().unstack().plot(kind='bar',stacked=True)

# %%
plt.hist(train_0['Vintage'],alpha=0.5, bins=50, label='0')
plt.hist(train_1['Vintage'],alpha=0.5, bins=50, label='1')
plt.legend()

# %%
train.Policy_Sales_Channel.value_counts()
# Out:
# 152.0    134784
# 26.0      79700
# 124.0     73995
# 160.0     21779
# 156.0     10661
#           ...
# 144.0         1
# 149.0         1
# 84.0          1
# 143.0         1
# 43.0          1
# Name: Policy_Sales_Channel, Length: 155, dtype: int64

# %%
train.groupby(['Gender','Response']).size().unstack().plot(kind='bar',stacked=True)

# %%
train['Vehicle_Age'].value_counts()
# Out:
# 1-2 Year     200316
# < 1 Year     164786
# > 2 Years     16007
# Name: Vehicle_Age, dtype: int64

# %%
dic_vage = {'< 1 Year':1,'1-2 Year':2,'> 2 Years':3}
dic_damage = {'Yes':1, 'No':0}

train.replace({'Vehicle_Age':dic_vage, 'Vehicle_Damage':dic_damage}, inplace=True)

# %%
cormat = train.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cormat, annot=True, fmt = '.3f')

# %%
# We can use laplace smoothing or encoding technique for categorical data with high cardinality

# %%
# remove id, vintage column, driving licence
# person age pd.cut and ordered encoding 5 cuts
# Map gender, vehicle damage to 0 or 1
# REgion code and Policy_sales_channel - frequency encoding
# vehicle age ordered encoding

# %%
def remove_columns(features,df):
    df = df.drop(features, axis=1)
    return df
    
def binary_map(features,df):
    for f in features:
        if f == 'Vehicle_Damage':
            dic_map = {'Yes':1, 'No':0}
        elif f == 'Vehicle_Age':
            dic_map = {'< 1 Year':1,'1-2 Year':2,'> 2 Years':3}
        else f == 'gender':
            dic_map = {'Male':1,'Female':0}
        df[f] = df[f].replace(dic_map)
    return df

def binning_age(df):
    df['Age'] = pd.cut(df['Age'],[0,20,40,60,80,100],labels=[1,2,3,4,5], include_lowest = True)
    return df

def freq_encode(features,df_train,df_test):   
    for f in features:
        map_dict = dict(zip(train[f].value_counts().index,range(1,train[f].nunique()+1)))
        df_train[f] = df_train[f].replace(map_dict)
        df_test[f] = df_test[f].replace(map_dict)
        
    return df_train, df_test

# %%
## Model Building

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

G

# %%
def select_model(df, features):
    
    all_X = df[features]
    all_y = df['Response']

    models = [
              
              {
               "name": "Decision Tree",
               "estimator": DecisionTreeRegressor(random_state=1),
               "hyperparameters": {'criterion': ["mse", "friedman_mse", "mae"],
                                 'min_samples_leaf': [30,50 ,100],
                                 'min_samples_split': [30,50,100]
                                 }
              },
              
              {
               "name": "Random Forest",
               "estimator":RandomForestRegressor(random_state=1),
               "hyperparameters": {'n_estimators':[500,1000],
                                   'criterion':['mse'],
                                   'min_samples_leaf': [30,50],
                                   'min_samples_split': [30,50],
                                   'n_jobs' : [-1]
                                   }
              }
        
            ]
    

    
    for model in models:
        print(model['name'])
        print('*'*len(model['name']))    
        
        grid = GridSearchCV(model['estimator'], param_grid=model['hyperparameters'], scoring='f1', cv=5)
        grid.fit(all_X,all_y)
        
        pred = grid.predict(all_X)
        
        model["best_params"] = grid.best_params_
#         model['best_score'] = grid.best_score_
        model['best_model'] = grid.best_estimator_

        
        print('RMSLE Score for best model: {:.4f}'.format(error))
        print('Best Params:{}\n'.format(model['best_params']))
        
    return models
